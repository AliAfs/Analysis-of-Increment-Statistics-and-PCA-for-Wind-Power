# %% [markdown]
# # AP1

# %%
from pandas import read_csv
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# Importing the data for turbineID1
data1 = read_csv('E:/Data-Engineering-Jacbos/Semester 2/Advanced Project/AP1/Data/1.csv', header=0, index_col=0, parse_dates=True)
data1.head()
# Out:
#                            100m wind speed (m/s)  \
# Date(YYYY-MM-DD hh:mm:ss)
# 2006-01-01 00:00:00                         5.12
# 2006-01-01 00:10:00                         5.12
# 2006-01-01 00:20:00                         5.14
# 2006-01-01 00:30:00                         5.17
# 2006-01-01 00:40:00                         5.24
#
#                             rated power output at 100m (MW)  \
# Date(YYYY-MM-DD hh:mm:ss)
# 2006-01-01 00:00:00                                   1.788
# 2006-01-01 00:10:00                                   1.788
# 2006-01-01 00:20:00                                   1.812
# 2006-01-01 00:30:00                                   1.848
# 2006-01-01 00:40:00                                   1.929
#
#                             SCORE-lite power output at 100m (MW)  \
# Date(YYYY-MM-DD hh:mm:ss)
# 2006-01-01 00:00:00                                        2.012
# 2006-01-01 00:10:00                                        2.227
# 2006-01-01 00:20:00                                        0.130
# 2006-01-01 00:30:00                                        2.311
# 2006-01-01 00:40:00                                        1.849
#
#                            CorrectedScore
# Date(YYYY-MM-DD hh:mm:ss)
# 2006-01-01 00:00:00                 2.012
# 2006-01-01 00:10:00                 2.227
# 2006-01-01 00:20:00                 0.130
# 2006-01-01 00:30:00                 2.311
# 2006-01-01 00:40:00                 1.849

# %%
# Plotting the time series for turbineID1 - whole year
data1["100m wind speed (m/s)"].plot()
# Out:
# <AxesSubplot:xlabel='Date(YYYY-MM-DD hh:mm:ss)'>

# %%
print ('Number of samples:', len(data1))
# Out:
# Number of samples: 52560

# %%
# extracting the data for January
data1_Jan = data1['2006-01-01':'2006-01-31']

# %%
data1_Jan.tail()
# Out:
#                            100m wind speed (m/s)  \
# Date(YYYY-MM-DD hh:mm:ss)
# 2006-01-31 23:10:00                        12.20
# 2006-01-31 23:20:00                        11.95
# 2006-01-31 23:30:00                        11.17
# 2006-01-31 23:40:00                        10.82
# 2006-01-31 23:50:00                        10.71
#
#                             rated power output at 100m (MW)  \
# Date(YYYY-MM-DD hh:mm:ss)
# 2006-01-31 23:10:00                                  24.315
# 2006-01-31 23:20:00                                  23.391
# 2006-01-31 23:30:00                                  20.325
# 2006-01-31 23:40:00                                  18.861
# 2006-01-31 23:50:00                                  18.390
#
#                             SCORE-lite power output at 100m (MW)  \
# Date(YYYY-MM-DD hh:mm:ss)
# 2006-01-31 23:10:00                                       26.878
# 2006-01-31 23:20:00                                       22.563
# 2006-01-31 23:30:00                                       20.754
# 2006-01-31 23:40:00                                       18.891
# 2006-01-31 23:50:00                                       20.031
#
#                            CorrectedScore
# Date(YYYY-MM-DD hh:mm:ss)
# 2006-01-31 23:10:00                26.878
# 2006-01-31 23:20:00                22.563
# 2006-01-31 23:30:00                20.754
# 2006-01-31 23:40:00                18.891
# 2006-01-31 23:50:00                20.031

# %%
# Plotting the wind speed time series for turbine 1
data1_Jan["100m wind speed (m/s)"].plot()
# Out:
# <AxesSubplot:xlabel='Date(YYYY-MM-DD hh:mm:ss)'>

# %%
# Plotting the wind speed histogram for turbine 1 
plt.hist(data1_Jan ["100m wind speed (m/s)"],bins = 40)
  
plt.title('Histogram of Wind speed for TurbineID1')
plt.xlabel('Wind speed at 100m [m/s]')
plt.ylabel('Count')
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

# %%
# Plotting the output power for turbine 1
data1_Jan[" rated power output at 100m (MW)"].plot()
# Out:
# <AxesSubplot:xlabel='Date(YYYY-MM-DD hh:mm:ss)'>

# %%
# Plotting the output power histogram for turbine 1
plt.hist(data1_Jan [" rated power output at 100m (MW)"],bins = 40)
  
plt.title('Histogram of the Output Power for TurbineID1')
plt.xlabel('Rated power output at 100m (MW)')
plt.ylabel('Count')
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

# %%
# Importing data for turbineID2
data2 = read_csv('E:/Data-Engineering-Jacbos/Semester 2/Advanced Project/AP1/Data/2.csv', header=0, index_col=0, parse_dates=True)
data2.head()
# Out:
#                            100m wind speed (m/s)  \
# Date(YYYY-MM-DD hh:mm:ss)
# 2006-01-01 00:00:00                         5.29
# 2006-01-01 00:10:00                         5.30
# 2006-01-01 00:20:00                         5.33
# 2006-01-01 00:30:00                         5.37
# 2006-01-01 00:40:00                         5.43
#
#                             rated power output at 100m (MW)  \
# Date(YYYY-MM-DD hh:mm:ss)
# 2006-01-01 00:00:00                                   2.007
# 2006-01-01 00:10:00                                   2.016
# 2006-01-01 00:20:00                                   2.067
# 2006-01-01 00:30:00                                   2.127
# 2006-01-01 00:40:00                                   2.229
#
#                             SCORE-lite power output at 100m (MW)  \
# Date(YYYY-MM-DD hh:mm:ss)
# 2006-01-01 00:00:00                                        1.628
# 2006-01-01 00:10:00                                        1.211
# 2006-01-01 00:20:00                                        1.161
# 2006-01-01 00:30:00                                        2.428
# 2006-01-01 00:40:00                                        2.084
#
#                            CorrectedScore
# Date(YYYY-MM-DD hh:mm:ss)
# 2006-01-01 00:00:00                 1.628
# 2006-01-01 00:10:00                 1.211
# 2006-01-01 00:20:00                 1.161
# 2006-01-01 00:30:00                 2.428
# 2006-01-01 00:40:00                 2.084

# %%
## extracting the data for January
data2_Jan = data2['2006-01-01':'2006-01-31']
data2_Jan.tail()
# Out:
#                            100m wind speed (m/s)  \
# Date(YYYY-MM-DD hh:mm:ss)
# 2006-01-31 23:10:00                        12.23
# 2006-01-31 23:20:00                        11.97
# 2006-01-31 23:30:00                        11.17
# 2006-01-31 23:40:00                        10.82
# 2006-01-31 23:50:00                        10.70
#
#                             rated power output at 100m (MW)  \
# Date(YYYY-MM-DD hh:mm:ss)
# 2006-01-31 23:10:00                                  24.423
# 2006-01-31 23:20:00                                  23.484
# 2006-01-31 23:30:00                                  20.316
# 2006-01-31 23:40:00                                  18.837
# 2006-01-31 23:50:00                                  18.363
#
#                             SCORE-lite power output at 100m (MW)  \
# Date(YYYY-MM-DD hh:mm:ss)
# 2006-01-31 23:10:00                                       23.225
# 2006-01-31 23:20:00                                       23.041
# 2006-01-31 23:30:00                                       21.707
# 2006-01-31 23:40:00                                       19.402
# 2006-01-31 23:50:00                                       18.153
#
#                            CorrectedScore
# Date(YYYY-MM-DD hh:mm:ss)
# 2006-01-31 23:10:00                23.225
# 2006-01-31 23:20:00                23.041
# 2006-01-31 23:30:00                21.707
# 2006-01-31 23:40:00                19.402
# 2006-01-31 23:50:00                18.153

# %%
# Plotting the scatter plot for wind speed for turbine 1 and 2
plt.scatter(data1_Jan['100m wind speed (m/s)'],data2_Jan['100m wind speed (m/s)'])

plt.title('Wind Speed for turbineID1 and turbineID2')
plt.xlabel('Wind Speed - TurbineID1')
plt.ylabel('Wind Speed - TurbineID2')
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

# %%
# Finding the correlation coefficient for wind speed between turbine 1 and 2 
correlation = data1_Jan['100m wind speed (m/s)'].corr(data2_Jan['100m wind speed (m/s)'])
print ('Correlation Coefficient =',correlation)
# Out:
# Correlation Coefficient = 0.9978388207353805

# %%
# Plotting the scatter plot for output power for turbine 1 and 2
plt.scatter(data1_Jan[' rated power output at 100m (MW)'],data2_Jan[' rated power output at 100m (MW)'])

plt.title('Output Power for turbineID1 and turbineID2')
plt.xlabel('Output Power - TurbineID1')
plt.ylabel('Output Power - TurbineID2')
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

# %%
# Finding the correlation coefficient for output power between turbine 1 and 2 
correlation = data1_Jan[' rated power output at 100m (MW)'].corr(data2_Jan[' rated power output at 100m (MW)'])
print ('Correlation Coefficient =',correlation)
# Out:
# Correlation Coefficient = 0.9968891697303828

# %%
# Extracting hour, day and wind speed data for turbineID1 in January
hour = data1_Jan.index.hour
day = data1_Jan.index.day
windspeed = data1_Jan['100m wind speed (m/s)']

# %%
d = {'hour':hour, 'day':day, 'windspeed':windspeed}
df = pd.DataFrame (data=d)

# %%
# Plotting heatmap for turbineID1
import seaborn as sns
hm1 = df.pivot_table(index="hour",columns="day",values="windspeed", aggfunc="mean")
sns.heatmap(hm1, annot=False, cmap="magma", cbar_kws={'label': 'Wind Speed'})
# Out:
# <AxesSubplot:xlabel='day', ylabel='hour'>

# %%
# Plotting heatmap for turbineID1

xgrid = np.arange(day.max() + 1) + 1
# Hours start at 0, length 2
ygrid = np.arange(25)
fig, ax = pyplot.subplots()
ax.pcolormesh(xgrid, ygrid, hm1, cmap="magma")
ax.set_frame_on(False) # remove all spines
ax.set_ylim(24, 0)
# Out:
# (24.0, 0.0)

# %%
MIN_WS = data1['100m wind speed (m/s)'].min()
MAX_WS = data1['100m wind speed (m/s)'].max()

# Plotting heatmap for whole year 2006 for turbine 1

import matplotlib.colors as mc # For the legend

def single_plot (data, month, ax):
    data = data[data.index.month == month]
    hour = data.index.hour
    day = data.index.day
    WindSpeed = data['100m wind speed (m/s)']
    #WindSpeed = WindSpeed.values.reshape(24, len(day.unique()), order="F")
    d = {'hour':hour, 'day':day, 'windspeed':WindSpeed}
    df = pd.DataFrame (data=d)
    WindSpeed = df.pivot_table(index="hour",columns="day",values="windspeed", aggfunc="mean")

    xgrid = np.arange(day.max() + 1) + 1
    ygrid = np.arange(25)
    
    ax.pcolormesh(xgrid, ygrid, WindSpeed, cmap="magma", vmin=MIN_WS, vmax=MAX_WS)
    # Invert the vertical axis
    ax.set_ylim(24, 0)
    # Set tick positions for both axes
    ax.yaxis.set_ticks([i for i in range(24)])
    ax.xaxis.set_ticks([10, 20, 30])
    # Remove ticks by setting their length to 0
    ax.yaxis.set_tick_params(length=0)
    ax.xaxis.set_tick_params(length=0)
    
    # Remove all spines
    ax.set_frame_on(False)
    

fig, axes = plt.subplots(1, 12, figsize=(14, 5), sharey=True)

for i in range(1,13):
    single_plot(data1, i, axes[i-1])
    
fig.subplots_adjust(left=0.05, right=0.98, top=0.9, hspace=0.08, wspace=0.04)

# Another utility for the legend
from matplotlib.cm import ScalarMappable

# First, let's make some room for the legend in the bottom.
fig.subplots_adjust(bottom=0.15)

# Create a new axis to contain the color bar
# Values are:
# (x coordinate of left border, 
#  y coordinate for bottom border,
#  width,
#  height)
cbar_ax = fig.add_axes([0.3, 0.005, 0.4, 0.025])

# Create a normalizer that goes from minimum to maximum temperature
norm = mc.Normalize(MIN_WS, MAX_WS)

# Create the colorbar and set it to horizontal
cb = fig.colorbar(
    ScalarMappable(norm=norm, cmap="magma"), 
    cax=cbar_ax, # Pass the new axis
    orientation = "horizontal"
)

# Remove tick marks
cb.ax.xaxis.set_tick_params(size=0)

# Set legend label
cb.set_label("Wind Speed", size=12)
#fig

# Set common labels for x and y axes
fig.text(0.5, 0.08, "Day", ha="center", va="center", fontsize=14)
fig.text(0.02, 0.5, 'Hour', ha="center", va="center", rotation="vertical", fontsize=14)

fig.suptitle("Hourly Wind Speed (January) - Turbine 1", fontsize=20, y=0.97)
#fig
# Out:
# Text(0.5, 0.97, 'Hourly Wind Speed (January) - Turbine 1')

# %%
    data = data1_Jan
    data = data[data.index.day == day]
    hour = data.index.hour
    minute = data.index.minute
    WindSpeed = data['100m wind speed (m/s)']
    #WindSpeed = WindSpeed.values.reshape(24, len(day.unique()), order="F")
    d = {'hour':hour, 'minute':minute, 'windspeed':WindSpeed}
    df = pd.DataFrame (data=d)
    WindSpeed = df.pivot_table(index="minute",columns="hour",values="windspeed", aggfunc="mean")
    WindSpeed
# Out:
# hour          0         1         2         3         4         5         6   \
# minute
# 0       8.354194  8.503548  8.753871  8.852258  8.696129  8.820323  9.039355
# 10      8.386452  8.479355  8.760968  8.781935  8.746774  8.941935  9.104516
# 20      8.345806  8.425484  8.687419  8.773226  8.762903  8.990645  9.072581
# 30      8.336129  8.428710  8.600645  8.710968  8.774194  9.088387  8.995484
# 40      8.470323  8.542903  8.610323  8.687742  8.796129  9.087742  8.983548
# 50      8.504516  8.721935  8.696452  8.699032  8.820968  9.040000  8.992903
#
# hour          7         8         9   ...        14        15        16  \
# minute                                ...
# 0       9.022258  8.843226  9.206774  ...  7.999032  7.569032  6.777742
# 10      9.067419  8.827419  9.217097  ...  7.994516  7.524516  6.669677
# 20      8.979032  8.824516  9.230000  ...  7.877097  7.464516  6.534194
# 30      8.948710  8.852903  9.228065  ...  7.800323  7.238065  6.456774
# 40      8.945161  8.865484  9.313548  ...  7.739032  7.091935  6.459032
# 50      8.890323  8.938387  9.271613  ...  7.683871  6.949032  6.506129
#
# hour          17        18        19        20        21        22        23
# minute
# 0       6.470968  6.713871  6.995161  7.134839  7.250000  7.449355  7.902903
# 10      6.398710  6.704839  7.002903  7.149355  7.243871  7.540000  7.988387
# 20      6.458387  6.850000  7.010323  7.160000  7.294516  7.665484  8.064194
# 30      6.679677  6.970968  7.042581  7.206774  7.391613  7.744516  8.243871
# 40      6.758065  7.002258  7.121290  7.225484  7.481290  7.812581  8.444194
# 50      6.772581  7.004194  7.111613  7.227097  7.473226  7.887742  8.615161
#
# [6 rows x 24 columns]

# %%
import glob

# Import data for all 10 turbines
path = r'E:/Data-Engineering-Jacbos/Semester 2/Advanced Project/AP1/Data'                     # use your path
all_files = glob.glob(path + "/*.csv")     # advisable to use os.path.join as this makes concatenation OS independent

df_from_each_file = (pd.read_csv(f) for f in all_files)
data_all = pd.concat(df_from_each_file, ignore_index=True)

# %%
# Plotting histogram of wind speed for all turbines
plt.hist(data_all ["100m wind speed (m/s)"],bins = 40)
  
plt.title('Histogram of Wind speed for All Turbines')
plt.xlabel('Wind speed at 100m [m/s]')
plt.ylabel('Count')
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

# %%
# Plotting histogram of output power for all turbines
plt.hist(data_all [" rated power output at 100m (MW)"],bins = 20)
  
plt.title('Histogram of Output Power for All Turbines')
plt.xlabel('Rated power output at 100m (MW)')
plt.ylabel('Count')
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

# %%
data_all.head()
# Out:
#   Date(YYYY-MM-DD hh:mm:ss)  100m wind speed (m/s)  \
# 0       2006-01-01 00:00:00                   5.12
# 1       2006-01-01 00:10:00                   5.12
# 2       2006-01-01 00:20:00                   5.14
# 3       2006-01-01 00:30:00                   5.17
# 4       2006-01-01 00:40:00                   5.24
#
#     rated power output at 100m (MW)   SCORE-lite power output at 100m (MW)  \
# 0                             1.788                                  2.012
# 1                             1.788                                  2.227
# 2                             1.812                                  0.130
# 3                             1.848                                  2.311
# 4                             1.929                                  1.849
#
#    CorrectedScore
# 0           2.012
# 1           2.227
# 2           0.130
# 3           2.311
# 4           1.849

# %%
len(data_all)
# Out:
# 525600

# %%
k = len(data1)
WindSpeed_dic = {}
for i in range(10):
    WindSpeed_dic['TurbineID{}'.format(i+1)] = list(data_all['100m wind speed (m/s)'][i*k:(i+1)*k])

WindSpeed_df = pd.DataFrame(data=WindSpeed_dic)
WindSpeed_df
# Out:
#        TurbineID1  TurbineID2  TurbineID3  TurbineID4  TurbineID5  TurbineID6  \
# 0            5.12        5.83        5.29        5.47        4.69        5.03
# 1            5.12        5.93        5.30        5.48        4.75        5.10
# 2            5.14        6.04        5.33        5.53        4.84        5.17
# 3            5.17        6.14        5.37        5.58        4.92        5.25
# 4            5.24        6.29        5.43        5.66        5.03        5.36
# ...           ...         ...         ...         ...         ...         ...
# 52555        6.24        5.92        6.33        6.42        5.84        5.89
# 52556        6.14        5.86        6.25        6.37        5.70        5.77
# 52557        5.95        5.73        6.07        6.20        5.54        5.61
# 52558        5.86        5.74        5.95        6.07        5.53        5.56
# 52559        5.85        5.84        5.90        5.98        5.58        5.59
#
#        TurbineID7  TurbineID8  TurbineID9  TurbineID10
# 0            5.31        5.51        5.17         5.59
# 1            5.38        5.57        5.28         5.70
# 2            5.45        5.65        5.41         5.81
# 3            5.53        5.73        5.53         5.93
# 4            5.63        5.83        5.69         6.08
# ...           ...         ...         ...          ...
# 52555        5.95        5.99        5.84         5.90
# 52556        5.85        5.92        5.72         5.82
# 52557        5.68        5.76        5.63         5.70
# 52558        5.61        5.67        5.68         5.73
# 52559        5.63        5.66        5.80         5.85
#
# [52560 rows x 10 columns]

# %%
corrMatrix = WindSpeed_df.corr()
print (corrMatrix)
# Out:
#              TurbineID1  TurbineID2  TurbineID3  TurbineID4  TurbineID5  \
# TurbineID1     1.000000    0.925666    0.997400    0.988763    0.982329
# TurbineID2     0.925666    1.000000    0.935048    0.949421    0.949471
# TurbineID3     0.997400    0.935048    1.000000    0.996460    0.976842
# TurbineID4     0.988763    0.949421    0.996460    1.000000    0.969566
# TurbineID5     0.982329    0.949471    0.976842    0.969566    1.000000
# TurbineID6     0.989399    0.959843    0.988496    0.984529    0.995054
# TurbineID7     0.984777    0.972165    0.989053    0.990790    0.984923
# TurbineID8     0.969327    0.984286    0.978662    0.987847    0.969077
# TurbineID9     0.947633    0.977839    0.947601    0.949466    0.983793
# TurbineID10    0.944587    0.994263    0.949450    0.957216    0.972609
#
#              TurbineID6  TurbineID7  TurbineID8  TurbineID9  TurbineID10
# TurbineID1     0.989399    0.984777    0.969327    0.947633     0.944587
# TurbineID2     0.959843    0.972165    0.984286    0.977839     0.994263
# TurbineID3     0.988496    0.989053    0.978662    0.947601     0.949450
# TurbineID4     0.984529    0.990790    0.987847    0.949466     0.957216
# TurbineID5     0.995054    0.984923    0.969077    0.983793     0.972609
# TurbineID6     1.000000    0.996428    0.984525    0.979932     0.977376
# TurbineID7     0.996428    1.000000    0.995222    0.976411     0.982117
# TurbineID8     0.984525    0.995222    1.000000    0.970807     0.984716
# TurbineID9     0.979932    0.976411    0.970807    1.000000     0.994017
# TurbineID10    0.977376    0.982117    0.984716    0.994017     1.000000

# %%
# Plotting correlation matrix for wind speed
sns.heatmap(corrMatrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
k = len(data1)
PowerOut_dic = {}
for i in range(10):
    PowerOut_dic['TurbineID{}'.format(i+1)] = list(data_all[' rated power output at 100m (MW)'][i*k:(i+1)*k])

PowerOut_df = pd.DataFrame(data=PowerOut_dic)
PowerOut_df
# Out:
#        TurbineID1  TurbineID2  TurbineID3  TurbineID4  TurbineID5  TurbineID6  \
# 0           1.788       2.829       2.007       2.280       1.317       1.689
# 1           1.788       2.976       2.016       2.295       1.386       1.755
# 2           1.812       3.144       2.067       2.370       1.473       1.839
# 3           1.848       3.309       2.127       2.460       1.563       1.932
# 4           1.929       3.531       2.229       2.580       1.686       2.103
# ...           ...         ...         ...         ...         ...         ...
# 52555       3.642       3.069       3.828       4.029       2.961       3.042
# 52556       3.453       2.976       3.660       3.903       2.733       2.853
# 52557       3.153       2.775       3.339       3.543       2.493       2.589
# 52558       3.009       2.787       3.150       3.324       2.469       2.520
# 52559       2.997       2.955       3.075       3.195       2.556       2.571
#
#        TurbineID7  TurbineID8  TurbineID9  TurbineID10
# 0           2.028       2.334       1.833        2.457
# 1           2.124       2.427       1.974        2.616
# 2           2.241       2.550       2.169        2.799
# 3           2.358       2.670       2.361        2.976
# 4           2.517       2.829       2.607        3.213
# ...           ...         ...         ...          ...
# 52555       3.126       3.186       2.946        3.045
# 52556       2.979       3.081       2.763        2.907
# 52557       2.709       2.823       2.613        2.730
# 52558       2.601       2.685       2.694        2.778
# 52559       2.622       2.676       2.889        2.958
#
# [52560 rows x 10 columns]

# %%
# Correlation matrix for output power
corrMatrix = PowerOut_df.corr()
print (corrMatrix)
# Out:
#              TurbineID1  TurbineID2  TurbineID3  TurbineID4  TurbineID5  \
# TurbineID1     1.000000    0.914286    0.997181    0.987953    0.978277
# TurbineID2     0.914286    1.000000    0.923319    0.938678    0.937854
# TurbineID3     0.997181    0.923319    1.000000    0.996174    0.971075
# TurbineID4     0.987953    0.938678    0.996174    1.000000    0.962018
# TurbineID5     0.978277    0.937854    0.971075    0.962018    1.000000
# TurbineID6     0.988008    0.948450    0.986066    0.980586    0.993508
# TurbineID7     0.983771    0.962285    0.987584    0.988392    0.981007
# TurbineID8     0.967269    0.977121    0.976499    0.985442    0.962581
# TurbineID9     0.937052    0.971227    0.935446    0.936623    0.979199
# TurbineID10    0.936512    0.992554    0.940518    0.948414    0.966671
#
#              TurbineID6  TurbineID7  TurbineID8  TurbineID9  TurbineID10
# TurbineID1     0.988008    0.983771    0.967269    0.937052     0.936512
# TurbineID2     0.948450    0.962285    0.977121    0.971227     0.992554
# TurbineID3     0.986066    0.987584    0.976499    0.935446     0.940518
# TurbineID4     0.980586    0.988392    0.985442    0.936623     0.948414
# TurbineID5     0.993508    0.981007    0.962581    0.979199     0.966671
# TurbineID6     1.000000    0.995714    0.982008    0.971081     0.970011
# TurbineID7     0.995714    1.000000    0.994506    0.965214     0.974537
# TurbineID8     0.982008    0.994506    1.000000    0.958472     0.977836
# TurbineID9     0.971081    0.965214    0.958472    1.000000     0.992131
# TurbineID10    0.970011    0.974537    0.977836    0.992131     1.000000

# %%
# Plotting correlation matrix for wind speed
sns.heatmap(corrMatrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
# Decomposing the time series for turbineID1
from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse
from pylab import rcParams
rcParams['figure.figsize'] = 15, 12

# Additive Decomposition
result_add = seasonal_decompose(data1 ["100m wind speed (m/s)"], model='additive', extrapolate_trend='freq', period=6*24)
# Plot
result_add.plot().suptitle('Additive Decompose', fontsize=22,y=1.03)
# Out:
# Text(0.5, 1.03, 'Additive Decompose')

# %%
data3 = read_csv('E:/Data-Engineering-Jacbos/Semester 2/Advanced Project/AP1/Data/3.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
data4 = read_csv('E:/Data-Engineering-Jacbos/Semester 2/Advanced Project/AP1/Data/4.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
data5 = read_csv('E:/Data-Engineering-Jacbos/Semester 2/Advanced Project/AP1/Data/5.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
data6 = read_csv('E:/Data-Engineering-Jacbos/Semester 2/Advanced Project/AP1/Data/6.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
data7 = read_csv('E:/Data-Engineering-Jacbos/Semester 2/Advanced Project/AP1/Data/7.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
data8 = read_csv('E:/Data-Engineering-Jacbos/Semester 2/Advanced Project/AP1/Data/8.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
data9 = read_csv('E:/Data-Engineering-Jacbos/Semester 2/Advanced Project/AP1/Data/9.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
data10 = read_csv('E:/Data-Engineering-Jacbos/Semester 2/Advanced Project/AP1/Data/10.csv', header=0, index_col=0, parse_dates=True, squeeze=True)

# %%
hour = data1.index.hour
day = data1.index.day
month = data1.index.month
windspeed = data1['100m wind speed (m/s)']
d = {'hour':hour, 'day':day, 'month': month, 'windspeed':windspeed}
df = pd.DataFrame (data=d)
df.tail()
# Out:
#                            hour  day  month  windspeed
# Date(YYYY-MM-DD hh:mm:ss)
# 2006-12-31 23:10:00          23   31     12       6.24
# 2006-12-31 23:20:00          23   31     12       6.14
# 2006-12-31 23:30:00          23   31     12       5.95
# 2006-12-31 23:40:00          23   31     12       5.86
# 2006-12-31 23:50:00          23   31     12       5.85

# %%
df_list = list()
for i in range(1,13):
    df_list.append(data1['2006-{}-01'.format(i):'2006-{}-28'.format(i)])
    
# beacuse Feb has 28 days, all month projected with 28 days! Alternative method?!

# %%
''''
MIN_WS = data1_Jan['100m wind speed (m/s)'].min()
MAX_WS = data1_Jan['100m wind speed (m/s)'].max()

# Plotting heatmap for whole year 2006 for turbine 1

import matplotlib.colors as mc # For the legend
import matplotlib.pyplot as plt

def single_plot (data, day, ax):
    data = data[data.index.day == day]
    hour = data.index.hour
    minute = data.index.minute
    WindSpeed = data['100m wind speed (m/s)']
    #WindSpeed = WindSpeed.values.reshape(24, len(day.unique()), order="F")
    d = {'hour':hour, 'minute':minute, 'windspeed':WindSpeed}
    df = pd.DataFrame (data=d)
    WindSpeed = df.pivot_table(index="minute",columns="hour",values="windspeed")#, aggfunc="mean")

    xgrid = np.arange(25)
    ygrid = np.arange(7)
    
    ax.pcolormesh(xgrid, ygrid, WindSpeed, cmap="magma", vmin=MIN_WS, vmax=MAX_WS)
    # Invert the vertical axis
    ax.set_ylim(60, 0)
    # Set tick positions for both axes
    ax.yaxis.set_ticks([i for i in range(60)])
    #ax.xaxis.set_ticks([10, 20, 30])
    # Remove ticks by setting their length to 0
    ax.yaxis.set_tick_params(length=0)
    ax.xaxis.set_tick_params(length=0)
    
    # Remove all spines
    ax.set_frame_on(False)
    

fig, axes = plt.subplots(1, 31, figsize=(14, 5), sharey=True)

for i in range(1,32):
    single_plot(data1_Jan, i, axes[i-1])
    
fig.subplots_adjust(left=0.05, right=0.98, top=0.9, hspace=0.08, wspace=0.04)



# Another utility for the legend
from matplotlib.cm import ScalarMappable

# First, let's make some room for the legend in the bottom.
fig.subplots_adjust(bottom=0.15)

# Create a new axis to contain the color bar
# Values are:
# (x coordinate of left border, 
#  y coordinate for bottom border,
#  width,
#  height)
cbar_ax = fig.add_axes([0.3, 0.005, 0.4, 0.025])

# Create a normalizer that goes from minimum to maximum temperature
norm = mc.Normalize(MIN_WS, MAX_WS)

# Create the colorbar and set it to horizontal
cb = fig.colorbar(
    ScalarMappable(norm=norm, cmap="magma"), 
    cax=cbar_ax, # Pass the new axis
    orientation = "horizontal"
)

# Remove tick marks
cb.ax.xaxis.set_tick_params(size=0)

# Set legend label
cb.set_label("Wind Speed", size=12)
#fig

# Set common labels for x and y axes
fig.text(0.5, 0.08, "Day", ha="center", va="center", fontsize=14)
fig.text(0.02, 0.5, 'Hour', ha="center", va="center", rotation="vertical", fontsize=14)

fig.suptitle("Hourly Wind Speed - Turbine 1", fontsize=20, y=0.97)
#fig
'''
# Out:
# '\'\nMIN_WS = data1_Jan[\'100m wind speed (m/s)\'].min()\nMAX_WS = data1_Jan[\'100m wind speed (m/s)\'].max()\n\n# Plotting heatmap for whole year 2006 for turbine 1\n\nimport matplotlib.colors as mc # For the legend\nimport matplotlib.pyplot as plt\n\ndef single_plot (data, day, ax):\n    data = data[data.index.day == day]\n    hour = data.index.hour\n    minute = data.index.minute\n    WindSpeed = data[\'100m wind speed (m/s)\']\n    #WindSpeed = WindSpeed.values.reshape(24, len(day.unique()), order="F")\n    d = {\'hour\':hour, \'minute\':minute, \'windspeed\':WindSpeed}\n    df = pd.DataFrame (data=d)\n    WindSpeed = df.pivot_table(index="minute",columns="hour",values="windspeed")#, aggfunc="mean")\n\n    xgrid = np.arange(25)\n    ygrid = np.arange(7)\n    \n    ax.pcolormesh(xgrid, ygrid, WindSpeed, cmap="magma", vmin=MIN_WS, vmax=MAX_WS)\n    # Invert the vertical axis\n    ax.set_ylim(60, 0)\n    # Set tick positions for both axes\n    ax.yaxis.set_ticks([i for i in range(60)])\n    #ax.xaxis.set_ticks([10, 20, 30])\n    # Remove ticks by setting their length to 0\n    ax.yaxis.set_tick_params(length=0)\n    ax.xaxis.set_tick_params(length=0)\n    \n    # Remove all spines\n    ax.set_frame_on(False)\n    \n\nfig, axes = plt.subplots(1, 31, figsize=(14, 5), sharey=True)\n\nfor i in range(1,32):\n    single_plot(data1_Jan, i, axes[i-1])\n    \nfig.subplots_adjust(left=0.05, right=0.98, top=0.9, hspace=0.08, wspace=0.04)\n\n\n\n# Another utility for the legend\nfrom matplotlib.cm import ScalarMappable\n\n# First, let\'s make some room for the legend in the bottom.\nfig.subplots_adjust(bottom=0.15)\n\n# Create a new axis to contain the color bar\n# Values are:\n# (x coordinate of left border, \n#  y coordinate for bottom border,\n#  width,\n#  height)\ncbar_ax = fig.add_axes([0.3, 0.005, 0.4, 0.025])\n\n# Create a normalizer that goes from minimum to maximum temperature\nnorm = mc.Normalize(MIN_WS, MAX_WS)\n\n# Create the colorbar and set it to horizontal\ncb = fig.colorbar(\n    ScalarMappable(norm=norm, cmap="magma"), \n    cax=cbar_ax, # Pass the new axis\n    orientation = "horizontal"\n)\n\n# Remove tick marks\ncb.ax.xaxis.set_tick_params(size=0)\n\n# Set legend label\ncb.set_label("Wind Speed", size=12)\n#fig\n\n# Set common labels for x and y axes\nfig.text(0.5, 0.08, "Day", ha="center", va="center", fontsize=14)\nfig.text(0.02, 0.5, \'Hour\', ha="center", va="center", rotation="vertical", fontsize=14)\n\nfig.suptitle("Hourly Wind Speed - Turbine 1", fontsize=20, y=0.97)\n#fig\n'
